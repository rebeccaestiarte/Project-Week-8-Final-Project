# %% [markdown]
# # DATA EXPLORATION & PROCESSING

# %%
import pandas as pd

import statsmodels.api as sm
from matplotlib import pyplot as plt

import mne
# %matplotlib inline
import numpy as np
mne.set_log_level('WARNING')

import matplotlib.pyplot as plt
import chart_studio.plotly as py
import plotly.graph_objs as go

import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot

# %%
test = pd.read_csv("/Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/test.csv")

# %% [markdown]
# ## DATA EXPLORATION

# %%
test

# %%
test = test.head(2000)

# %%
test.dtypes

# %%
test.columns

# %%
test.dtypes.isna().sum()

# %% [markdown]
# ## DATA CLEANING

# %%
# Creating Dataframe for each brainwave type
Delta = test[["Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10"]]
Theta = test[['Theta_TP9', 'Theta_AF7', 'Theta_AF8', 'Theta_TP10']]
Alpha = test[['Alpha_TP9','Alpha_AF7', 'Alpha_AF8', 'Alpha_TP10']]
Beta = test[['Beta_TP9', 'Beta_AF7', 'Beta_AF8', 'Beta_TP10']]
Gamma = test[['Gamma_TP9', 'Gamma_AF7', 'Gamma_AF8','Gamma_TP10']]

time = test["TimeStamp"]

# %%
# Adding mean of recording by brainwave type and adding on new column
brainwaves = ["Delta", "Theta", "Alpha", "Beta", "Gamma"]

def calculate_mean_bw(df, brainwave):
    df[brainwave] = df.mean(axis=1)
    return df[brainwave]

calculate_mean_bw(Delta, "Delta") 
calculate_mean_bw(Theta, "Theta") 
calculate_mean_bw(Alpha, "Alpha") 
calculate_mean_bw(Beta, "Beta") 
calculate_mean_bw(Gamma, "Gamma")

# %%
#Concatenating all results into a dataframe

result_tot = pd.concat([time, Delta, Theta, Alpha, Beta, Gamma], axis=1, sort=False)
result_tot

# %%
result_tot.describe()

# %%
result_tot.isna().sum()

# %%
theta_avg = Theta.round(5)
theta_avg = pd.DataFrame(theta_avg["Theta"].value_counts()).reset_index().rename(columns={"index":"theta"})
theta_avg = theta_avg.drop(columns = ["Theta"])

delta_avg = Delta.round(5)
delta_avg = pd.DataFrame(delta_avg["Delta"].value_counts()).reset_index().rename(columns={"index":"delta"})
delta_avg = delta_avg.drop(columns = ["Delta"])

alpha_avg = Alpha.round(5)
alpha_avg = pd.DataFrame(alpha_avg["Alpha"].value_counts()).reset_index().rename(columns={"index":"alpha"})
alpha_avg = alpha_avg.drop(columns = ["Alpha"])

beta_avg = Beta.round(5)
beta_avg = pd.DataFrame(beta_avg["Beta"].value_counts()).reset_index().rename(columns={"index":"beta"})
beta_avg = beta_avg.drop(columns = ["Beta"])

gamma_avg = Gamma.round(5)
gamma_avg = pd.DataFrame(gamma_avg["Gamma"].value_counts()).reset_index().rename(columns={"index":"gamma"})
gamma_avg = gamma_avg.drop(columns = ["Gamma"])

result_avg = pd.concat([theta_avg, delta_avg, alpha_avg, beta_avg, gamma_avg], axis=1, sort=False)
result_avg

# %%
result_avg.describe()

# %%
sns.distplot(result_avg["gamma"])

# %%
import seaborn as sns

sns.distplot(result_avg["alpha"])
sns.distplot(result_avg["theta"])
sns.distplot(result_avg["delta"])
sns.distplot(result_avg["beta"])
sns.distplot(result_avg["gamma"])

data = pd.DataFrame(result_avg["gamma"])
qqplot(data, line='s')
plt.show()

# %%
result_avg.head()

# %%
time = test["TimeStamp"] #have to add time somehow
data = test[["delta","alpha", "beta", "gamma", "theta"]]

columns = ["Delta_TP9", "Alpha_TP9","Beta_TP9", "Gamma_TP9", "Theta_TP9"]

# %%
test[["Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10",'Theta_TP9', 'Theta_AF7', 'Theta_AF8', 'Theta_TP10','Alpha_TP9','Alpha_AF7', 'Alpha_AF8', 'Alpha_TP10','Beta_TP9', 'Beta_AF7', 'Beta_AF8', 'Beta_TP10','Gamma_TP9', 'Gamma_AF7', 'Gamma_AF8','Gamma_TP10']].head(200)

# %%
test[["Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10",'Theta_TP9', 'Theta_AF7', 'Theta_AF8', 'Theta_TP10','Alpha_TP9','Alpha_AF7', 'Alpha_AF8', 'Alpha_TP10','Beta_TP9', 'Beta_AF7', 'Beta_AF8', 'Beta_TP10','Gamma_TP9', 'Gamma_AF7', 'Gamma_AF8','Gamma_TP10']].tail(200)

# %%
test.describe()

# %% [markdown]
# ## EXTRAS

# %%
load('demo_data')
brain_fig = plot_mesh_brain(brain_data.pial_right)
brain_data = get(gca, 'Children')

# extract brain data from figure

# handle vertices
x_data = brain_data(2).Vertices(:,1)
y_data = brain_data(2).Vertices(:,2)
z_data = brain_data(2).Vertices(:,3)

# specify how vertices connect to form the faces
i_data = brain_data(2).Faces(:,1)-1
j_data = brain_data(2).Faces(:,2)-1
k_data = brain_data(2).Faces(:,3)-1

# construct plotly figure
brain_plotly_fig = plotlyfig('visible', 'off', 'strip', false, 'world_readable', false); 
brain_plotly_data.x = x_data
brain_plotly_data.y = y_data
brain_plotly_data.z = z_data
brain_plotly_data.i = i_data
brain_plotly_data.j = j_data
brain_plotly_data.k = k_data
brain_plotly_data.type = 'mesh3d'
brain_plotly_data.intensity = x_data
brain_plotly_data.colorscale = 'Electric'

# add a second trace for 3D scatter points
points_of_interest = [100, 1000, 10000]
scatter_plotly_data.x = x_data(points_of_interest)
scatter_plotly_data.y = y_data(points_of_interest)
scatter_plotly_data.z = z_data(points_of_interest)
scatter_plotly_data.marker.size=20
scatter_plotly_data.marker.color='yellow'
scatter_plotly_data.marker.opacity='0.4'
scatter_plotly_data.mode = 'markers'
scatter_plotly_data.type= 'scatter3d'

# add data
brain_plotly_fig.data = {brain_plotly_data, scatter_plotly_data};

# adjust the layout
brain_plotly_fig.layout.scene.xaxis.dtick = 30
brain_plotly_fig.layout.scene.yaxis.dtick = 30
brain_plotly_fig.layout.scene.zaxis.dtick = 30
# Out:
#   File "<ipython-input-30-b28d5e261216>", line 8
#     x_data = brain_data(2).Vertices(:,1)
#                                     ^
# SyntaxError: invalid syntax

# %%
# h0 : mu1 != mu2
# H1: mu1 = mu2

#https://towardsdatascience.com/hypothesis-testing-in-real-life-47f42420b1f7

# %% [markdown]
# ## DATA PROCESSING

# %%
#Importing all dataframes and saving them into list

import glob
path = "/Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/" 
all_files = glob.glob(path + "/*.csv")

sessions_N = []
sessions_M = []

for filename in all_files:
    session = pd.read_csv(filename, index_col=None, header=0) # Reading file
    if "Normal" in filename: #Classifing as 0 if Normal Session
        session["Activity"] = 0 
        sessions_N.append(session)
    elif "Meditative" in filename: #Classifing as 1 if Meditation Session
        session["Activity"] = 1 
        sessions_M.append(session)
    
    print(filename)
# Out:
# /Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/museMonitor - Normal_2020-03-06--15-40-52_1183768195786381480.csv
# /Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/museMonitor- Meditative - 2020-03-08--13-25-44_-1804549122.csv
# /Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/museMonitor- Normal - Domingo - 2020-03-08--16-39-05_1616914376.csv
# /Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/museMonitor - Meditative_2020-03-06--15-19-04_4355290272618263162.csv
# /Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/museMonitor - Normal_2020-03-06--14-13-47_2885111221865233217.csv
# /Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/museMonitor - Normal_2020-03-06--22-24-04_7721039972580483693.csv
# /Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Raw Data/museMonitor - Normal_Valentin_2020-03-07--15-20-42_3655243791061482298.csv

# %%
# Cleaning all dataframes and saving into new list 

simplified_sessions_N = []
simplified_sessions_M = []

for session in sessions_N:
    session.drop(columns = ["AUX_RIGHT", "Accelerometer_X", "Accelerometer_Y", "Accelerometer_Z","Gyro_X","Gyro_Y", "Gyro_Z","HeadBandOn", "HSI_TP9","HSI_AF7","HSI_AF8","HSI_TP10","Battery","Elements"], inplace=True)
    session.dropna(inplace = True)
    session["Delta"] = session[["Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10"]].mean(axis=1)
    session["Theta"] = session[['Theta_TP9', 'Theta_AF7', 'Theta_AF8', 'Theta_TP10']].mean(axis=1)
    session["Alpha"] = session[['Alpha_TP9','Alpha_AF7', 'Alpha_AF8', 'Alpha_TP10']].mean(axis=1)
    session["Beta"] = session[['Beta_TP9', 'Beta_AF7', 'Beta_AF8', 'Beta_TP10']].mean(axis=1)
    session["Gamma"] = session[['Gamma_TP9', 'Gamma_AF7', 'Gamma_AF8','Gamma_TP10']].mean(axis=1)
    
    simplified_session = session[["TimeStamp", "Delta", "Theta", "Alpha", "Beta", "Gamma", "Activity"]]
    simplified_sessions_N.append(simplified_session) 
    
for session in sessions_M:
    session.drop(columns = ["AUX_RIGHT", "Accelerometer_X", "Accelerometer_Y", "Accelerometer_Z","Gyro_X","Gyro_Y", "Gyro_Z","HeadBandOn", "HSI_TP9","HSI_AF7","HSI_AF8","HSI_TP10","Battery","Elements"], inplace=True)
    session.dropna(inplace = True)
    session["Delta"] = session[["Delta_TP9", "Delta_AF7", "Delta_AF8", "Delta_TP10"]].mean(axis=1)
    session["Theta"] = session[['Theta_TP9', 'Theta_AF7', 'Theta_AF8', 'Theta_TP10']].mean(axis=1)
    session["Alpha"] = session[['Alpha_TP9','Alpha_AF7', 'Alpha_AF8', 'Alpha_TP10']].mean(axis=1)
    session["Beta"] = session[['Beta_TP9', 'Beta_AF7', 'Beta_AF8', 'Beta_TP10']].mean(axis=1)
    session["Gamma"] = session[['Gamma_TP9', 'Gamma_AF7', 'Gamma_AF8','Gamma_TP10']].mean(axis=1)
    
    simplified_session = session[["TimeStamp", "Delta", "Theta", "Alpha", "Beta", "Gamma", "Activity"]]
    simplified_sessions_M.append(simplified_session)

# %%
#GETTING AGGREGATE AVG OF ALL SESSIONS ON NORMAL STATE -> Improve!

df_concat = pd.concat((simplified_sessions_N[0], simplified_sessions_N[1], simplified_sessions_N[2],simplified_sessions_N[3],simplified_sessions_N[4]))
by_row_index = df_concat.groupby(df_concat.index)
df_normal_means = by_row_index.mean()
df_normal_means
# Out:
#          Delta     Theta     Alpha      Beta     Gamma  Activity
# 0     0.778308  0.624626  0.729796  0.604488  0.233707         0
# 1     0.649729  0.280919  0.522667  0.585046  0.293771         0
# 2     0.425133  0.295851  0.544735  0.579859  0.229691         0
# 4     0.737942  0.427591  0.499999  0.510366  0.228409         0
# 6     0.083281  0.068663  0.544377  0.407564  0.012432         0
# ...        ...       ...       ...       ...       ...       ...
# 1075  0.592204  0.629364  0.695148  0.664153  0.466014         0
# 1079  0.592204  0.629364  0.695148  0.664153  0.466014         0
# 1084  0.592204  0.629364  0.695148  0.664153  0.466014         0
# 1088  0.592204  0.629364  0.695148  0.664153  0.466014         0
# 1093  0.592204  0.629364  0.695148  0.664153  0.466014         0
#
# [835 rows x 6 columns]

# %%
df_concat = pd.concat((simplified_sessions_M[0], simplified_sessions_M[1]))
by_row_index = df_concat.groupby(df_concat.index)
df_meditation_means = by_row_index.mean()
df_meditation_means
# Out:
#         Delta     Theta     Alpha      Beta     Gamma  Activity
# 0    0.628527  0.494501  0.741988  0.537194  0.204631         1
# 1    0.522841  0.521011  0.770994  0.401369  0.036043         1
# 3    0.486290  0.270794  0.485314  0.439144  0.087487         1
# 4    0.671006  0.384073  0.625955  0.366554 -0.081616         1
# 5    0.467385  0.398626  1.020102  0.399266  0.013233         1
# ..        ...       ...       ...       ...       ...       ...
# 629  0.379933  0.524331  0.602478  0.367161 -0.100731         1
# 630  0.486866  0.586745  0.662457  0.299507 -0.214737         1
# 633  0.509248  0.503306  0.612052  0.252555 -0.352738         1
# 636  0.493008  0.558436  0.756088  0.352018 -0.217968         1
# 637  0.621671  0.692250  0.823054  0.356050 -0.108683         1
#
# [581 rows x 6 columns]

# %% [markdown]
# ## DESCRIPTIVE STATISTICS

# %%
brainwaves = ["Delta", "Theta", "Alpha","Beta", "Gamma"]
colors = ["Red", "Orange", "Yellow", "Green", "Blue"]
wave_to_color = dict(zip(brainwaves, colors))


def multiline_waves(dataframe):
    
    """The function generates a multi-line plot of all the brainwaves"""
    
    x = dataframe.index #dataframe["TimeStamp"]
    df = dataframe[["Delta", "Theta", "Alpha","Beta", "Gamma"]]

    plt.figure(figsize=(20,10))
    num=0
    for brainwave in brainwaves:
        num+=1
        plt.plot(x, df[brainwave], marker='', color=wave_to_color.get(brainwave), linewidth=1, alpha=0.9, label=brainwave)
    
    plt.legend(fontsize=15)
    plt.title("EGG Brainwaves", loc='left', fontsize=20, fontweight=1, color='black')
    plt.xlabel("Time", fontsize=15)
    plt.ylabel("EGG", fontsize=15)

def histogram_qq_waves(dataframe):
  
    """The function shows graphically the distribution of each brainwave"""
    
    for brainwave in brainwaves:
        plt.figure(brainwave)
        sns.distplot(dataframe[brainwave], color=wave_to_color.get(brainwave))
        qqplot(pd.DataFrame(dataframe[brainwave]), line='s')
        

def line_wave(dataframe, state):
    
    """The function shows graphically the pattern of each brainwave in the session"""
    
    x = dataframe.index #dataframe["TimeStamp"]
    df = dataframe[["Delta", "Theta", "Alpha","Beta", "Gamma"]]

    for brainwave in brainwaves:
        plt.plot(x, df[brainwave], marker='', color=wave_to_color.get(brainwave), linewidth=1, alpha=0.9, label=brainwave)
        plt.title(f"{brainwave, state} State") 
        plt.ylabel("time", fontsize = 10)
        plt.xlabel(f"{brainwave}", fontsize = 10)
        plt.show()
        plt.savefig("/Users/rebeccaestiarte/Desktop/IronHack/PROJECTS/Project-Week-8-Final-Project/your-project/Export Figures/{state}.png", dpi = 400, quality = 100)

# %%
line_wave(df_normal_means, "Normal")

# %%
line_wave(df_meditation_means)

# %% [markdown]
# #### TESTING WITH AGGREGATED DATAFRAME

# %%
df_meditation_means.describe()
# Out:
#             Delta       Theta       Alpha        Beta       Gamma  Activity
# count  581.000000  581.000000  581.000000  581.000000  581.000000     581.0
# mean     0.401517    0.245182    0.664913    0.216135   -0.167107       1.0
# std      0.305362    0.217254    0.118863    0.069608    0.088654       0.0
# min     -0.360627   -0.300643    0.274184    0.027912   -0.421010       1.0
# 25%      0.192578    0.083806    0.588593    0.173184   -0.226331       1.0
# 50%      0.414313    0.214883    0.665283    0.209629   -0.172262       1.0
# 75%      0.612087    0.377773    0.733695    0.254967   -0.118260       1.0
# max      1.308465    0.944923    1.195067    0.537194    0.204631       1.0

# %%
df_normal_means.describe()
# Out:
#             Delta       Theta       Alpha        Beta       Gamma  Activity
# count  835.000000  835.000000  835.000000  835.000000  835.000000     835.0
# mean     0.333833    0.238516    0.495192    0.426201    0.121429       0.0
# std      0.273013    0.259630    0.263123    0.208883    0.236353       0.0
# min     -0.771495   -0.924349   -0.716637   -0.480360   -0.818910       0.0
# 25%      0.163280    0.110663    0.400325    0.324837   -0.013256       0.0
# 50%      0.349833    0.260813    0.552520    0.460020    0.122949       0.0
# 75%      0.523087    0.401225    0.663260    0.571600    0.259823       0.0
# max      1.038676    0.961050    0.948855    0.936770    0.842306       0.0

# %%
multiline_waves(df_meditation_means)

# %%
multiline_waves(df_normal_means)

# %% [markdown]
# #### NORMAL STATE SESSIONS ANALYSIS

# %%
simplified_sessions[0].describe()

# %%
multiline_waves(simplified_sessions[0])

# %%
histogram_qq_waves(simplified_sessions[0])

# %% [markdown]
# > The distribution of the Brainwaves follows a Normal Distribution

# %% [markdown]
# #### MEDITATIVE STATE SESSIONS ANALYSIS

# %%
simplified_sessions[1].describe() #for final table Meditation sessions

# %%
multiline_waves(simplified_sessions[1])

# %%
histogram_qq_waves(simplified_sessions[1])

# %% [markdown]
# ## HYPOTESIS TESTING

# %% [markdown]
# h0 : mu1 != mu2
# h1: mu1 = mu2
#
# https://towardsdatascience.com/hypothesis-testing-in-real-life-47f42420b1f7
#
# I will use the t-test to compare the mean of two given samples as the population parameters (mean and standard deviation) are not known. I assumed a normal distribution of the sample.
#
# I will use the independent samples t-test as I am comparing the mean for two independent groups.

# %%
mu1 = simplified_sessions[0][["Delta", "Theta", "Alpha","Beta", "Gamma"]].mean()
std1 = simplified_sessions[0][["Delta", "Theta", "Alpha","Beta", "Gamma"]].std()
n1 = simplified_sessions[0][["Delta", "Theta", "Alpha","Beta", "Gamma"]].shape[0]

# %%
mu2 = simplified_sessions[1][["Delta", "Theta", "Alpha","Beta", "Gamma"]].mean()
std2 = simplified_sessions[1][["Delta", "Theta", "Alpha","Beta", "Gamma"]].std()
n2 = simplified_sessions[1][["Delta", "Theta", "Alpha","Beta", "Gamma"]].shape[0]

# %%
from scipy import stats

t_score = stats.ttest_ind_from_stats(mu1,std1,n1, mu2,std2,n2, equal_var=False) #welch test-> not assuming equal variances in population
t_score

alpha = 0.5 #confidence interval of 90%

# %% [markdown]
# >If we observe a large p-value, for example larger than 0.05 or 0.1, then we cannot reject the null hypothesis of identical average scores. If the p-value is smaller than the threshold, e.g. 1%, 5% or 10%, then we reject the null hypothesis of equal averages.
